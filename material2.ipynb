# %%
import vaex
import pylab as plt
# Out:
# Bad key "xtick.top" on line 5 in
# /Users/maartenbreddels/.matplotlib/stylelib/bigfont.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://github.com/matplotlib/matplotlib/blob/master/matplotlibrc.template
# or from the matplotlib source distribution
#
# Bad key "ytick.right" on line 6 in
# /Users/maartenbreddels/.matplotlib/stylelib/bigfont.mplstyle.
# You probably need to get an updated matplotlibrc file from
# http://github.com/matplotlib/matplotlib/blob/master/matplotlibrc.template
# or from the matplotlib source distribution

# %%
ds = vaex.open("/Users/maartenbreddels/src/vaex/data/helmi-dezeeuw-2000-FeH.hdf5")

# %%
ds.plot_widget("Lz", "E", f="log")

# %%
plt.style.use("bigfont")

# %%
ds.plot1d("Lz", show=True, figsize=(10,6), hardcopy="counts_1d.png")

# %%
gaia =

# %%
ds.plot("x", "y", show=True, figsize=(10,6), hardcopy="counts_2d.png", f="log")#, selection=[False, True])

# %%
ds.plot_widget("x", "y", "z", f="log", smooth_pre=0.5, selection=True, backend="ipyvolume", shape=128)

# %%
import ipyvolume.pylab as p3

# %%
f = p3.gcf()

# %%
f.screen_capture_enabled = True

# %%
p3.savefig("count_3d.png")
# Out:
# 'count_3d.png'

# %%
ds.plot("x", "y", show=True, figsize=(10,6), hardcopy="stat_2d.png", what="correlation(vx, vz)")#, selection=[False, True])

# %%
ds.plot1d("Lz", show=True, figsize=(10,6), hardcopy="stat_1d.png", what="mean(E)")

# %%
ds.plot_widget("x", "y", "z", backend="ipyvolume", shape=128, what="mean(FeH+5)", smooth_pre=1.0)#, f="log")

# %%
ds.count()
# Out:
# 3300000.0

# %%
ds.mean("x")
# Out:
# -0.083443628960842398
